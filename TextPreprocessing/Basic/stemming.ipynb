# %% [markdown]
# #### In grammer, inflection is the modification of a word to express different grammatical categories such as tense, case, voice, aspect, person, number, gender, and mood.
#
# ##### ex: do -> un-do, do-able, un-do-able

# %% [markdown]
# ### Stemming: It is the process of reducing inflection in words to their root forms such as mapping a group of words to same stem even if the stem itself is not a valid word in the language
#
# #### EX: Information Retrieval System

# %%
# !pip install --upgrade pip setuptools wheel
# !pip install --upgrade numpy scipy bottleneck numexpr nltk
# !pip install --force-reinstall --no-binary :all: bottleneck numexpr
# Out:
# ...
#   Using cached pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# ...
# Using cached pip-25.2-py3-none-any.whl (1.8 MB)
# ERROR: To modify pip, please run the following command:
# C:\Users\user\anaconda3\python.exe -m pip install --upgrade pip setuptools wheel
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.8 kB 165.2 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.8 kB 245.8 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 294.0 kB/s eta 0:00:00
# ...
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# ...
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/38.6 MB 1.3 MB/s eta 0:00:30
# ...

# %%
from nltk.stem.porter import PorterStemmer

# %%
ps = PorterStemmer()

def stem_words(text):
    return " ".join([ps.stem(word) for word in text.split()])

# %%
text = "walk walks walking walked"

stem_words(text)
# Out:
# 'walk walk walk walk'

# %%
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize

stemmer = PorterStemmer()
text = "I was running late to the meeting, but I managed to finish all my assignments quickly. The children were playing outside, and the dogs were barking loudly."

tokens = word_tokenize(text)
stemmed_words = [stemmer.stem(word) for word in tokens]
print(stemmed_words)
# Out:
# ['i', 'wa', 'run', 'late', 'to', 'the', 'meet', ',', 'but', 'i', 'manag', 'to', 'finish', 'all', 'my', 'assign', 'quickli', '.', 'the', 'children', 'were', 'play', 'outsid', ',', 'and', 'the', 'dog', 'were', 'bark', 'loudli', '.']
